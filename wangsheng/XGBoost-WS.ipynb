# %%
import pandas as pd
import numpy as np
from sklearn import decomposition, metrics
from sklearn.model_selection import train_test_split
import xgboost as xgb
data = pd.read_csv('https://raw.githubusercontent.com/LyuCheng95/CVD/master/t3-smoking.csv', delimiter = ',')
x,y = data.iloc[:,:-1], data.iloc[:,-1]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)
for i in range(10,200,10):
    for j in range(1,51,5):
        xg_reg = xgb.XGBRegressor(objective ="binary:logistic", n_estimators = i, learning_rate=j/100)
        xg_reg.fit(x_train,y_train)
        ypred_bst = xg_reg.predict(x_test)
        ypred_bst  = ypred_bst >= 0.5  
        ypred_bst = ypred_bst.astype(int)
        
        if(metrics.recall_score(y_test,ypred_bst)>0.7):
            print("i: ",i,"j: ",j)
            #print("accuracy:", metrics.accuracy_score(y_test,ypred_bst))
            print("recall", metrics.recall_score(y_test,ypred_bst))
            #print("f1", metrics.f1_score(y_test,ypred_bst))
# Out:
# i:  10 j:  1
# i:  10 j:  6
# i:  10 j:  11
# i:  10 j:  16
# i:  10 j:  21
# i:  10 j:  26
# i:  10 j:  31
# i:  10 j:  36
# i:  10 j:  41
# i:  10 j:  46
# i:  20 j:  1
# i:  20 j:  6
# i:  20 j:  11
# i:  20 j:  16
# i:  20 j:  21
# i:  20 j:  26
# i:  20 j:  31
# i:  20 j:  36
# i:  20 j:  41
# i:  20 j:  46
# i:  30 j:  1
# i:  30 j:  6
# i:  30 j:  11
# i:  30 j:  16
# i:  30 j:  21
# i:  30 j:  26
# i:  30 j:  31
# i:  30 j:  36
# i:  30 j:  41
# i:  30 j:  46
# i:  40 j:  1
# i:  40 j:  6
# i:  40 j:  11
# i:  40 j:  16
# i:  40 j:  21
# i:  40 j:  26
# i:  40 j:  31
# i:  40 j:  36
# i:  40 j:  41
# i:  40 j:  46
# i:  50 j:  1
# i:  50 j:  6
# i:  50 j:  11
# i:  50 j:  16
# i:  50 j:  21
# i:  50 j:  26
# i:  50 j:  31
# i:  50 j:  36
# i:  50 j:  41
# i:  50 j:  46
# i:  60 j:  1
# i:  60 j:  6
# i:  60 j:  11
# i:  60 j:  16
# i:  60 j:  21
# i:  60 j:  26
# i:  60 j:  31
# i:  60 j:  36
# i:  60 j:  41
# i:  60 j:  46
# i:  70 j:  1
# i:  70 j:  6
# i:  70 j:  11
# i:  70 j:  16
# i:  70 j:  21
# i:  70 j:  26
# i:  70 j:  31
# i:  70 j:  36
# i:  70 j:  41
# i:  70 j:  46
# i:  80 j:  1
# i:  80 j:  6
# i:  80 j:  11
# i:  80 j:  16
# i:  80 j:  21
# i:  80 j:  26
# i:  80 j:  31
# i:  80 j:  36
# i:  80 j:  41
# i:  80 j:  46
# i:  90 j:  1
# i:  90 j:  6
# i:  90 j:  11
# i:  90 j:  16
# i:  90 j:  21
# i:  90 j:  26
# i:  90 j:  31
# i:  90 j:  36
# i:  90 j:  41
# i:  90 j:  46
# i:  100 j:  1
# i:  100 j:  6
# i:  100 j:  11
# i:  100 j:  16
# i:  100 j:  21
# i:  100 j:  26
# i:  100 j:  31
# i:  100 j:  36
# i:  100 j:  41
# i:  100 j:  46
# i:  110 j:  1
# i:  110 j:  6
# i:  110 j:  11
# i:  110 j:  16
# i:  110 j:  21
# i:  110 j:  26
# i:  110 j:  31
# i:  110 j:  36
# i:  110 j:  41
# i:  110 j:  46
# i:  120 j:  1
# i:  120 j:  6
# i:  120 j:  11
# i:  120 j:  16
# i:  120 j:  21
# i:  120 j:  26
# i:  120 j:  31
# i:  120 j:  36
# i:  120 j:  41
# i:  120 j:  46
# i:  130 j:  1
# i:  130 j:  6
# i:  130 j:  11
# i:  130 j:  16
# i:  130 j:  21
# i:  130 j:  26
# i:  130 j:  31
# i:  130 j:  36
# i:  130 j:  41
# i:  130 j:  46
# i:  140 j:  1
# i:  140 j:  6
# i:  140 j:  11
# i:  140 j:  16
# i:  140 j:  21
# i:  140 j:  26
# i:  140 j:  31
# i:  140 j:  36
# i:  140 j:  41
# i:  140 j:  46
# i:  150 j:  1
# i:  150 j:  6
# i:  150 j:  11
# i:  150 j:  16
# i:  150 j:  21
# i:  150 j:  26
# i:  150 j:  31
# i:  150 j:  36
# i:  150 j:  41
# i:  150 j:  46
# i:  160 j:  1
# i:  160 j:  6
# i:  160 j:  11
# i:  160 j:  16
# i:  160 j:  21
# i:  160 j:  26
# i:  160 j:  31
# i:  160 j:  36
# i:  160 j:  41
# i:  160 j:  46
# i:  170 j:  1
# i:  170 j:  6
# i:  170 j:  11
# i:  170 j:  16
# i:  170 j:  21
# i:  170 j:  26
# i:  170 j:  31
# i:  170 j:  36
# i:  170 j:  41
# i:  170 j:  46
# i:  180 j:  1
# i:  180 j:  6
# i:  180 j:  11
# i:  180 j:  16
# i:  180 j:  21
# i:  180 j:  26
# i:  180 j:  31
# i:  180 j:  36
# i:  180 j:  41
# i:  180 j:  46
# i:  190 j:  1
# i:  190 j:  6
# i:  190 j:  11
# i:  190 j:  16
# i:  190 j:  21
# i:  190 j:  26
# i:  190 j:  31
# i:  190 j:  36
# i:  190 j:  41
# i:  190 j:  46
